# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://suvarnabhumi.psu.ac.th/tudb/googlemap/South-East-Asia/1'
response = requests.get(url)

# %%
url = 'https://suvarnabhumi.psu.ac.th/tudb/archaeologicalread/115'
response = requests.get(url)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/gpu/lib/python3.9/site-packages/urllib3/connection.py:196, in HTTPConnection._new_conn(self)
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#
# File ~/gpu/lib/python3.9/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~/gpu/lib/python3.9/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
# ...

# %%
response = requests.get(url)  
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <!-- Meta Tags -->
# <meta content="https://suvarnabhumi.psu.ac.th/tudb/thumbpic/full/archaeological_pic13851215312023-02-2517_58_40.JPG" property="og:image"/>
# <meta content="วัดชมชื่น" property="og:title">
# <meta content="หลุมขุดค้นวัดชมชื่นเป็นหลุมขุดค้นที่แสดงการอยู่อาศัยของมนุษย์อย่างต่อเนื่องภายในพื้นที่อุทยานประวัติศาสตร์ศรีสัชนาลัย โดยสามารถแบ่งออกเป็น 5 สมัยการใช้งานพื้นที่
#
# 1. สมัยก่อนประวัติศาสตร์ตอนปลาย (ราวพุทธศตวรรษที่ 9) พบร่องรอยการใช้งานลักษณะเป็นชุมชนขนาดเล็ก ดำรงชีพด้วยการหาของป่าล่าสัตว์
#
# 2. สมัยประวัติศาสตร์ตอนต้น ร่วมสมัยกับทวารวดี (ราวพุทธศตวรรษที่ 11-16) พบโครงกระดูกมนุษย์จำนวน 15 โครง หันศีรษะไปทางทิศตะวันตก ลักษณะเป็นการตั้งถิ่นฐานถาวรและมีขนาดชุมชนที่ใหญ่ขึ้น และพบการติดต่อกับชุมชนใกล้เคียงรวมถึงชุมชนอื่นภายนอก จากการพบหลักฐานทางโบราณคดีประเภท ลูกปัดแก้ว ลูกปัดหินคาร์เนเลียน และลูกปัดอาเกต
#
# ...

# %% [markdown]
# #Full Function

# %%
def thaiweb(url):
    response = requests.get(url)  
    soup = BeautifulSoup(response.content, 'html.parser')
    meta_tag = soup.find('meta', property='og:title')

    # Extract the content attribute value if the tag exists
    if meta_tag:
        og_description = meta_tag['content']
        print(og_description)
    else:
        print("Meta tag with property='og:description' not found.")
        og_description ="None"
    important_info = soup.find('meta', property='og:description')

    # Extract the content attribute value if the tag exists
    if important_info:
        important = important_info['content']
        print(important)
    else:
        print("important_info was not found.")
        important="None"

    reseach_info = soup.find('div', class_='tabcontent news_desc', id='tap1')

    # Check if the <div> was found and extract text
    if reseach_info:
        reseach= reseach_info.get_text(separator="\n", strip=True)
        print(reseach)
    else:
        print("reseach_info was not found.")
        reseach="None"
    refer_info= soup.find('div', class_='tabcontent news_desc', id='tap4')

    # Check if the <div> was found and extract text
    if refer_info:
        refer = refer_info.get_text(separator="\n", strip=True)
        print(refer)
    else:
        print("Trefer_info was not found.")
        refer="None"
    location = soup.find('td', class_='toppics', string=lambda text: 'ที่ตั้ง :' in text if text else False)

    # Check if the <td> was found and extract the text from the adjacent <td>
    if location :
        td_value = location.find_next_sibling('td', style='font-family:fontThaipridi;')
        if td_value:
            location_text = td_value.get_text(strip=True)
            print(location_text)
        else:
            print("location was not found.")
    else:
        print("location was not found.")
        location_text = "None"
    coordinates_info= soup.find('td', class_='toppics', string=lambda text: 'พิกัด :' in text if text else False)

    # Check if the <td> was found and extract the text from the adjacent <td>
    if coordinates_info:
        td_value = coordinates_info.find_next_sibling('td', style='font-family:fontThaipridi;')
        if td_value:
            coordinates = td_value.get_text(strip=True)
            print(coordinates)
        else:
            print("The adjacent <td> with the specified style was not found.")
            coordinates="None"
    else:
        print("The <td> with the text 'ที่ตั้ง :' was not found.")
        
    age_info= soup.find('td', class_='toppics', string=lambda text: 'อายุสมัย :' in text if text else False)

    # Check if the <td> was found and extract the text from the adjacent <td>
    if age_info:
        td_value = age_info.find_next_sibling('td', style=lambda value: value and 'font-family:fontThaipridi' in value)
        if td_value:
            age_text = td_value.get_text(strip=True)
            print(age_text)
        else:
            print("The adjacent <td> with the specified style was not found.")
    else:
        age_text="None"
        print("The <td> with the text 'อายุสมัย :' was not found.")
    river_info = soup.find('td', class_='toppics', string=lambda text: 'แหล่งน้ำสำคัญ :' in text if text else False)

    # Check if the <td> was found and extract the text from the adjacent <td>
    if river_info:
        td_value = river_info.find_next_sibling('td', style='font-family:fontThaipridi;')
        if td_value:
            river = td_value.get_text(strip=True)
            print(river)
        else:
            print("แหล่งน้ำสำคัญ was not found.")
    else:
        print("แหล่งน้ำสำคัญ was not found.")
        river="None"
    h3_tag = soup.find('h3', class_='text-main text-bold mb-0', string='วันที่เผยแพร่ข้อมูล')

    # Check if the <h3> was found and extract the text from the adjacent <span>
    if h3_tag:
        span_tag = h3_tag.find_next('span', class_='text-bold text-secondary fs-18')
        if span_tag:
            date_text = span_tag.get_text(strip=True)
            print(date_text)
        else:
            print("The adjacent <span> with the specified class was not found.")
    else:
        print("The <h3> with the text 'วันที่เผยแพร่ข้อมูล' was not found.")
        date_text="None"
    tag_info = soup.find('td', class_='toppics', string=lambda text: 'คำสำคัญ/ป้ายกำกับ' in text if text else False)

    # Check if the <td> was found and extract the text from the adjacent <td>
    if tag_info:
        td_value = tag_info.find_next_sibling('td', style=lambda value: value and 'font-family:fontThaipridi' in value)
        if td_value:
            # Extract text from all <span> elements within the <td>
            spans = td_value.find_all('span', class_='badge bg-secondary text-light')
            tags = [span.get_text(strip=True) for span in spans]
            print(tags)
        else:
            print("The adjacent <td> with the specified style was not found.")
    else:
        print("The <td> with the text 'คำสำคัญ/ป้ายกำกับ :' was not found.")
        tags="None"
    link_info = soup.find('meta', property='og:url')

# Check if the <meta> was found and extract the content attribute
    if link_info:
        link= link_info.get('content')
        print(link)
    else:
        print("link was not found.")
        link="None"
    return og_description ,important,reseach,refer,location_text,age_text,river,date_text,tags,link

# %%
import requests
from bs4 import BeautifulSoup

def thaiweb(url):
    response = requests.get(url)  
    soup = BeautifulSoup(response.content, 'html.parser')
    
    og_title = "None"
    og_description = "None"
    research = "None"
    refer = "None"
    location_text = "None"
    coordinates = "None"
    age_text = "None"
    river = "None"
    date_text = "None"
    tags = []
    link = "None"
    additional_info = "None"
    
    # Extract Open Graph title
    meta_tag = soup.find('meta', property='og:title')
    if meta_tag:
        og_title = meta_tag['content']
        print(og_title)
    
    # Extract Open Graph description
    important_info = soup.find('meta', property='og:description')
    if important_info:
        og_description = important_info['content']
        print(og_description)
    
    # Extract research information
    research_info = soup.find('div', class_='tabcontent news_desc', id='tap1')
    if research_info:
        research = research_info.get_text(separator="\n", strip=True)
        print(research)
    
    # Extract reference information
    refer_info = soup.find('div', class_='tabcontent news_desc', id='tap4')
    if refer_info:
        refer = refer_info.get_text(separator="\n", strip=True)
        print(refer)
    
    # Extract location information
    location = soup.find('td', class_='toppics', string=lambda text: 'ที่ตั้ง :' in text if text else False)
    if location:
        td_value = location.find_next_sibling('td', style='font-family:fontThaipridi;')
        if td_value:
            location_text = td_value.get_text(strip=True)
            print(location_text)
    
    # Extract coordinates information
    coordinates_info = soup.find('td', class_='toppics', string=lambda text: 'พิกัด :' in text if text else False)
    if coordinates_info:
        td_value = coordinates_info.find_next_sibling('td', style='font-family:fontThaipridi;')
        if td_value:
            coordinates = td_value.get_text(strip=True)
            print(coordinates)
    
    # Extract age information
    age_info = soup.find('td', class_='toppics', string=lambda text: 'อายุสมัย :' in text if text else False)
    if age_info:
        td_value = age_info.find_next_sibling('td', style=lambda value: value and 'font-family:fontThaipridi' in value)
        if td_value:
            age_text = td_value.get_text(strip=True)
            print(age_text)
    
    # Extract river information
    river_info = soup.find('td', class_='toppics', string=lambda text: 'แหล่งน้ำสำคัญ :' in text if text else False)
    if river_info:
        td_value = river_info.find_next_sibling('td', style='font-family:fontThaipridi;')
        if td_value:
            river = td_value.get_text(strip=True)
            print(river)
    
    # Extract publication date
    h3_tag = soup.find('h3', class_='text-main text-bold mb-0', string='วันที่เผยแพร่ข้อมูล')
    if h3_tag:
        span_tag = h3_tag.find_next('span', class_='text-bold text-secondary fs-18')
        if span_tag:
            date_text = span_tag.get_text(strip=True)
            print(date_text)
    
    # Extract tags
    tag_info = soup.find('td', class_='toppics', string=lambda text: 'คำสำคัญ/ป้ายกำกับ' in text if text else False)
    if tag_info:
        td_value = tag_info.find_next_sibling('td', style=lambda value: value and 'font-family:fontThaipridi' in value)
        if td_value:
            spans = td_value.find_all('span', class_='badge bg-secondary text-light')
            tags = [span.get_text(strip=True) for span in spans]
            print(tags)
    
    # Extract link
    link_info = soup.find('meta', property='og:url')
    if link_info:
        link = link_info.get('content')
        print(link)
    
    # Extract additional information
    travel_info= soup.find('div', class_='toggle-inner pridi text-left', style='font-family: fontThaipridi !important;')
    if travel_info:
        travel = travel_info.get_text(separator="\n", strip=True)
        print(travel)
    
    return og_title, og_description, research, refer, location_text, coordinates, age_text, river, date_text, tags, link, travel

# %%
test = thaiweb("https://suvarnabhumi.psu.ac.th/tudb/archaeologicalread/121")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/gpu/lib/python3.9/site-packages/urllib3/connection.py:196, in HTTPConnection._new_conn(self)
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#
# File ~/gpu/lib/python3.9/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~/gpu/lib/python3.9/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
# ...

# %% [markdown]
# #Breakthrough  Function

# %%
meta_tag = soup.find('meta', property='og:title')

# Extract the content attribute value if the tag exists
if meta_tag:
    og_description = meta_tag['content']
    print(og_description)
else:
    print("Meta tag with property='og:description' not found.")
# Out:
# วัดชมชื่น

# %%
important_info = soup.find('meta', property='og:description')

# Extract the content attribute value if the tag exists
if important_info:
    important = important_info['content']
    print(important)
else:
    print("important_info was not found.")
# Out:
# หลุมขุดค้นวัดชมชื่นเป็นหลุมขุดค้นที่แสดงการอยู่อาศัยของมนุษย์อย่างต่อเนื่องภายในพื้นที่อุทยานประวัติศาสตร์ศรีสัชนาลัย โดยสามารถแบ่งออกเป็น 5 สมัยการใช้งานพื้นที่
#
# 1. สมัยก่อนประวัติศาสตร์ตอนปลาย (ราวพุทธศตวรรษที่ 9) พบร่องรอยการใช้งานลักษณะเป็นชุมชนขนาดเล็ก ดำรงชีพด้วยการหาของป่าล่าสัตว์
#
# 2. สมัยประวัติศาสตร์ตอนต้น ร่วมสมัยกับทวารวดี (ราวพุทธศตวรรษที่ 11-16) พบโครงกระดูกมนุษย์จำนวน 15 โครง หันศีรษะไปทางทิศตะวันตก ลักษณะเป็นการตั้งถิ่นฐานถาวรและมีขนาดชุมชนที่ใหญ่ขึ้น และพบการติดต่อกับชุมชนใกล้เคียงรวมถึงชุมชนอื่นภายนอก จากการพบหลักฐานทางโบราณคดีประเภท ลูกปัดแก้ว ลูกปัดหินคาร์เนเลียน และลูกปัดอาเกต
#
# 3. สมัยเขมรโบราณถึงสมัยสุโขทัย (ราวพุทธศตวรรษที่ 17-18) พบหลักฐานเป็นฐานอาคารทำจากอิฐจำนวน 3 หลัง ถูกใช้งานเป็นศาสนสถาน และมีร่องรอยการถูกน้ำท่วม ถูกสันนิษฐานว่าในระยะนี้เป็นช่วงที่มีการสร้างบ้านเมือง และมีศูนย์กลางชุมชนอยู่ในเขตเมืองเชลียง
#
# ...

# %%
reseach_info = soup.find('div', class_='tabcontent news_desc', id='tap1')

# Check if the <div> was found and extract text
if reseach_info:
    reseach= reseach_info.get_text(separator="\n", strip=True)
    print(reseach)
else:
    print("reseach_info was not found.")
# Out:
# - ค.ศ.1935 (พ.ศ.2478): กรมศิลปากรได้ประกาศกำหนดจำนวนโบราณสถานแห่งชาติ โดยประกาศในราชกิจจานุเบกษา เล่มที่ 52 ลงวันที่ 8 มีนาคม พ.ศ.2478 หน้า3701 โดยประกาศเพียงชื่อแต่ยังไม่ได้รับการกำหนดขอบเขตที่ชัดเจน
# - ค.ศ.1969-1970 (พ.ศ.2512-2513): หน่วยศิลปากรที่ 3 (ในขณะนั้น) ได้เข้าขุดแต่งบูรณะโบราณสถานวัดชมชื่น
# - ค.ศ.1988 (พ.ศ.2531): กรมศิลปากรได้ประกาศกำหนดเขตที่ดินโบราณสถานอุทยานประวัติศาสตร์ศรีสัชนาลัย โดยประกาศในราชกิจจานุเบกษา เล่มที่ 105 ตอนที่ 57 ลงวันที่ 12 เมษายน พ.ศ.2531 และในปีเดียวกันนั้น นักวิชาการชาวออสเตรเลียได้สำรวจพบชิ้นส่วนโครงกระดูกมนุษย์บริเวณริมตลิ่งด้านหน้าวัดชมชื่น และรายงานถึงเจ้าหน้าที่โครงการอุทยานประวัติศาสตร์ศรีสัชนาลัย จึงเกิดการขุดกู้โครงกระดูกจำนวน 1 โครง
# - ค.ศ.1993-1994 (พ.ศ.2536-2537): ได้รับการขุดค้นทางโบราณคดีโดยกรมศิลปากร นำโดยนายสถาพร เที่ยงธรรม โดยพบหลักฐานทางโบราณคดีทั้งโครงกระดูกมนุษย์สมัยประวัติศาสตร์ตอนต้น และการก่อสร้างอาคารซ้อนทับกันเป็นลำดับต่อเนื่องจนถึงสมัยสุโขทัย
# ...

# %%
refer_info= soup.find('div', class_='tabcontent news_desc', id='tap4')

# Check if the <div> was found and extract text
if refer_info:
    refer = refer_info.get_text(separator="\n", strip=True)
    print(refer)
else:
    print("Trefer_info was not found.")
# Out:
# ศูนย์มานุษยวิทยาสิรินธร (องค์การมหาชน). "ฐานข้อมูลแหล่งโบราณคดีที่สำคัญในประเทศไทย อาคารอนุรักษ์หลุมขุดค้นวัดชมชื่น"
# เข้าถึงได้จาก https://db.sac.or.th/archaeology/archaeology/451
# อุทยานประวัติศาสตรืศรีสัชนาลัย. "หลุมขุดค้นวัดชมชื่น". เข้าถึงได้จากhttps://www.facebook.com/335639723247529/posts/523068637837969/

# %%
location = soup.find('td', class_='toppics', string=lambda text: 'ที่ตั้ง :' in text if text else False)

# Check if the <td> was found and extract the text from the adjacent <td>
if location :
    td_value = location.find_next_sibling('td', style='font-family:fontThaipridi;')
    if td_value:
        location_text = td_value.get_text(strip=True)
        print(location_text)
    else:
        print("location was not found.")
else:
    print("location was not found.")
# Out:
# ตำบลศรีสัชนาลัย อำเภอศรีสัชนาลัย จังหวัดสุโขทัย

# %%
coordinates_info= soup.find('td', class_='toppics', string=lambda text: 'พิกัด :' in text if text else False)

# Check if the <td> was found and extract the text from the adjacent <td>
if coordinates_info:
    td_value = coordinates_info.find_next_sibling('td', style='font-family:fontThaipridi;')
    if td_value:
        location_text = td_value.get_text(strip=True)
        print(location_text)
    else:
        print("The adjacent <td> with the specified style was not found.")
else:
    print("The <td> with the text 'ที่ตั้ง :' was not found.")
# Out:
# 17.428 N, 99.806 E

# %%
age_info= soup.find('td', class_='toppics', string=lambda text: 'อายุสมัย :' in text if text else False)

# Check if the <td> was found and extract the text from the adjacent <td>
if age_info:
    td_value = age_info.find_next_sibling('td', style=lambda value: value and 'font-family:fontThaipridi' in value)
    if td_value:
        age_text = td_value.get_text(strip=True)
        print(age_text)
    else:
        print("The adjacent <td> with the specified style was not found.")
else:
    print("The <td> with the text 'อายุสมัย :' was not found.")
# Out:
# ระหว่าง ปี พ.ศ. 801 ถึง 2100

# %%
river_info = soup.find('td', class_='toppics', string=lambda text: 'แหล่งน้ำสำคัญ :' in text if text else False)

# Check if the <td> was found and extract the text from the adjacent <td>
if river_info:
    td_value = river_info.find_next_sibling('td', style='font-family:fontThaipridi;')
    if td_value:
        river = td_value.get_text(strip=True)
        print(river)
    else:
        print("แหล่งน้ำสำคัญ was not found.")
else:
    print("แหล่งน้ำสำคัญ was not found.")
# Out:
# แหล่งน้ำสำคัญ was not found.

# %%
h3_tag = soup.find('h3', class_='text-main text-bold mb-0', string='วันที่เผยแพร่ข้อมูล')

# Check if the <h3> was found and extract the text from the adjacent <span>
if h3_tag:
    span_tag = h3_tag.find_next('span', class_='text-bold text-secondary fs-18')
    if span_tag:
        date_text = span_tag.get_text(strip=True)
        print(date_text)
    else:
        print("The adjacent <span> with the specified class was not found.")
else:
    print("The <h3> with the text 'วันที่เผยแพร่ข้อมูล' was not found.")
# Out:
# 25 ก.พ. 2566

# %%
tag_info = soup.find('td', class_='toppics', string=lambda text: 'คำสำคัญ/ป้ายกำกับ' in text if text else False)

# Check if the <td> was found and extract the text from the adjacent <td>
if tag_info:
    td_value = tag_info.find_next_sibling('td', style=lambda value: value and 'font-family:fontThaipridi' in value)
    if td_value:
        # Extract text from all <span> elements within the <td>
        spans = td_value.find_all('span', class_='badge bg-secondary text-light')
        tags = [span.get_text(strip=True) for span in spans]
        print(tags)
    else:
        print("The adjacent <td> with the specified style was not found.")
else:
    print("The <td> with the text 'คำสำคัญ/ป้ายกำกับ :' was not found.")
# Out:
# ['หลุมฝังศพ', 'site museum', 'ลูกปัดหินคาร์เนเลียน', 'ราชวงศ์หมิง', 'จังหวัดสุโขทัย', 'ราชวงศ์ชิง', 'หินอาเกต']

# %%
link_info = soup.find('meta', property='og:url')

# Check if the <meta> was found and extract the content attribute
if link_info:
    link= link_info.get('content')
    print(link)
else:
    print("link was not found.")
# Out:
# https://suvarnabhumi.psu.ac.th/tudb/archaeologicalread/115

# %%
travel_info= soup.find('div', class_='toggle-inner pridi text-left', style='font-family: fontThaipridi !important;')
if travel_info:
    travel = travel_info.get_text(separator="\n", strip=True)
    print(travel)
# Out:
# - ค.ศ.1935 (พ.ศ.2478): กรมศิลปากรได้ประกาศกำหนดจำนวนโบราณสถานแห่งชาติ โดยประกาศในราชกิจจานุเบกษา เล่มที่ 52 ลงวันที่ 8 มีนาคม พ.ศ.2478 หน้า3701 โดยประกาศเพียงชื่อแต่ยังไม่ได้รับการกำหนดขอบเขตที่ชัดเจน
# - ค.ศ.1969-1970 (พ.ศ.2512-2513): หน่วยศิลปากรที่ 3 (ในขณะนั้น) ได้เข้าขุดแต่งบูรณะโบราณสถานวัดชมชื่น
# - ค.ศ.1988 (พ.ศ.2531): กรมศิลปากรได้ประกาศกำหนดเขตที่ดินโบราณสถานอุทยานประวัติศาสตร์ศรีสัชนาลัย โดยประกาศในราชกิจจานุเบกษา เล่มที่ 105 ตอนที่ 57 ลงวันที่ 12 เมษายน พ.ศ.2531 และในปีเดียวกันนั้น นักวิชาการชาวออสเตรเลียได้สำรวจพบชิ้นส่วนโครงกระดูกมนุษย์บริเวณริมตลิ่งด้านหน้าวัดชมชื่น และรายงานถึงเจ้าหน้าที่โครงการอุทยานประวัติศาสตร์ศรีสัชนาลัย จึงเกิดการขุดกู้โครงกระดูกจำนวน 1 โครง
# - ค.ศ.1993-1994 (พ.ศ.2536-2537): ได้รับการขุดค้นทางโบราณคดีโดยกรมศิลปากร นำโดยนายสถาพร เที่ยงธรรม โดยพบหลักฐานทางโบราณคดีทั้งโครงกระดูกมนุษย์สมัยประวัติศาสตร์ตอนต้น และการก่อสร้างอาคารซ้อนทับกันเป็นลำดับต่อเนื่องจนถึงสมัยสุโขทัย
# ...
